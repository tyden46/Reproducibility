# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ ggplot2 2.2.1     ✔ purrr   0.2.4
# ✔ tibble  1.4.2     ✔ dplyr   0.7.4
# ✔ tidyr   0.8.0     ✔ stringr 1.3.1
# ✔ readr   1.1.1     ✔ forcats 0.2.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
data=tribble(
  
  ~Year,	~Confidence,	~Total,
  "2007-2017 (n=1318)",	"CLow",	52.2,
  "2007-2017 (n=1318)",	"BMedium",	32.8,
  "2007-2017 (n=1318)",	"AHigh",	15,
  "2007 (n=27)",	"CLow",      37,
  "2007 (n=27)",	"BMedium",   25.9,
  "2007 (n=27)",	"AHigh",     37,
  "2008 (n=0)", "CLow",      	0,
  "2008 (n=0)", "BMedium",      	0,
  "2008 (n=0)", "AHigh",      	0,
  "2009 (n=129)", "CLow",	34.1,	
  "2009 (n=129)", "BMedium",	39.5,
  "2009 (n=129)", "AHigh",	26.4,
  "2010 (n=59)", "CLow",	23.7,
  "2010 (n=59)", "BMedium", 30.5,
  "2010 (n=59)",	"AHigh", 45.8,
  "2011 (n=24)",	"CLow", 16.7,
  "2011 (n=24)",	"BMedium", 41.7,
  "2011 (n=24)",	"AHigh",	41.7,
  "2012 (n=85)",	"CLow", 22.4,
  "2012 (n=85)",	"BMedium", 57.6,
  "2012 (n=85)",	"AHigh", 20,
  "2013 (n=332)",	"CLow", 34.9,
  "2013 (n=332)",	"BMedium",	46.7,
  "2013 (n=332)",	"AHigh",	18.4,
  "2014 (n=164)",	"CLow", 62.8,
  "2014 (n=164)",	"BMedium", 30.5,
  "2014 (n=164)",	"AHigh", 6.7,
  "2015 (n=243)",	"CLow", 67.9,
  "2015 (n=243)",	"BMedium", 26.8,
  "2015 (n=243)",	"AHigh", 5.3,
  "2016 (n=167)",	"CLow",	85.6,
  "2016 (n=167)",	"BMedium", 10.2,
  "2016 (n=167)",	"AHigh", 4.2,
  "2017 (n=98)",	"CLow", 76.5,
  "2017 (n=98)",	"BMedium",	14.3,
  "2017 (n=98)",	"AHigh",	9.2
)
data$Confidence=factor(data$Confidence, levels=c("AHigh","BMedium","CLow"), labels=c("High", "Medium", "Low"))
p<-ggplot(data, aes(x=Year, y=Total, fill=Confidence, label=Total, label=Total, width=0.37)) +
  geom_bar(stat="identity")+theme_minimal() +
  theme(axis.text.x = element_text(angle = 55, hjust = 1))+
  scale_fill_manual(values = c("lightgreen","firebrick1","deepskyblue")) +
  coord_fixed(0.06) +
  ggtitle("                                  Strength of Evidence by Year")+
  xlab("Year of Publication")+
  ylab("Percentage of Recommendations") +
  scale_y_continuous(breaks=seq(0, 100, 10))+
  geom_text(size = 5, position = position_stack(vjust = 0.5))

print(p)
# Out:
# Warning message:
# “The plyr::rename operation has created duplicates for the following name(s): (`label`)”
# plot without title
